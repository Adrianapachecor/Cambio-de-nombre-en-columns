# %%
# importar una librería
from google.colab import drive
drive.mount("/drive",force_remount=True)
# Out:
# Mounted at /drive

# %%
import pandas as pd
filename='/content/RailsToTrails_National_Count_Data_week (2).xlsx'
df = pd.read_excel(filename)
df
# Out:
#    Timeframe    Week of   2019 counts (31 counters)  \
# 0     Week 1 2020-12-30                    167679.0
# 1     Week 2 2020-01-06                     82340.0
# 2     Week 3 2020-01-13                     62315.0
# 3     Week 4 2020-01-20                     75801.0
# 4     Week 5 2020-01-27                     75841.0
# 5     Week 6 2020-02-03                     79780.0
# 6     Week 7 2020-02-10                     65732.0
# 7     Week 8 2020-02-17                     69492.0
# 8     Week 9 2020-02-24                     85688.0
# 9    Week 10 2020-03-02                     84512.0
# 10   Week 11 2020-03-09                    107995.0
# 11   Week 12 2020-03-16                    125440.0
# 12   Week 13 2020-03-23                    136330.0
# 13   Week 14 2020-03-30                    118784.0
# 14   Week 15 2020-04-06                    132033.0
# 15   Week 16 2020-04-13                    133267.0
# 16   Week 17 2020-04-20                    165777.0
# ...

# %%
df = df.drop(columns=['Unnamed: 7',
'Unnamed: 8',
'Unnamed: 9'])
df.head()
# Out:
#   Timeframe    Week of   2019 counts (31 counters)  \
# 0    Week 1 2020-12-30                    167679.0
# 1    Week 2 2020-01-06                     82340.0
# 2    Week 3 2020-01-13                     62315.0
# 3    Week 4 2020-01-20                     75801.0
# 4    Week 5 2020-01-27                     75841.0
#
#     2020 counts (31 counters)  2021 Counts  Change 2019-2020  Unnamed: 6
# 0                    183546.0          NaN          0.094627    1.094627
# 1                     97140.0          NaN          0.179743  117.974253
# 2                     75782.0          NaN          0.216112  121.611169
# 3                     83809.0          NaN          0.105645  110.564504
# 4                     94738.0          NaN          0.249166  124.916602

# %%
df=df.rename(columns={
                      'Unnamed: 6': 'percent_change',
                       'Timeframe': 'Timeframe',
                       'Week of': 'Week of',
                       '2019 counts (31 counters)': '2019 counts (31 counters)',
                       '2020 counts (31 counters)': '2020 counts (31 counters)',
                       '2021 Counts': '2021 Counts',
                       'Change 2019-2020': 'Change 2019-2020'})

df.columns = ['percent_change',
              'Timeframe',
              'Week of',
              '2019 counts (31 counters)',
              '2020 counts (31 counters)',
              '2021 Counts',
              'Change 2019-2020']
df.head()
# Out:
#   percent_change  Timeframe   Week of  2019 counts (31 counters)  \
# 0         Week 1 2020-12-30  167679.0                   183546.0
# 1         Week 2 2020-01-06   82340.0                    97140.0
# 2         Week 3 2020-01-13   62315.0                    75782.0
# 3         Week 4 2020-01-20   75801.0                    83809.0
# 4         Week 5 2020-01-27   75841.0                    94738.0
#
#    2020 counts (31 counters)  2021 Counts  Change 2019-2020
# 0                        NaN     0.094627          1.094627
# 1                        NaN     0.179743        117.974253
# 2                        NaN     0.216112        121.611169
# 3                        NaN     0.105645        110.564504
# 4                        NaN     0.249166        124.916602

# %%
df.info()
df.loc[0::,:].dropna(how = 'any')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   percent_change             52 non-null     object
#  1   Timeframe                  52 non-null     datetime64[ns]
#  2   Week of                    52 non-null     float64
#  3   2019 counts (31 counters)  52 non-null     float64
#  4   2020 counts (31 counters)  0 non-null      float64
#  5   2021 Counts                52 non-null     float64
#  6   Change 2019-2020           52 non-null     float64
# dtypes: datetime64[ns](1), float64(5), object(1)
# memory usage: 3.0+ KB
# Empty DataFrame
# Columns: [percent_change, Timeframe, Week of, 2019 counts (31 counters), 2020 counts (31 counters), 2021 Counts, Change 2019-2020]
# Index: []

# %%
df.loc[0:6, '2021 Counts']
df.head()
# Out:
#   percent_change  Timeframe   Week of  2019 counts (31 counters)  \
# 0         Week 1 2020-12-30  167679.0                   183546.0
# 1         Week 2 2020-01-06   82340.0                    97140.0
# 2         Week 3 2020-01-13   62315.0                    75782.0
# 3         Week 4 2020-01-20   75801.0                    83809.0
# 4         Week 5 2020-01-27   75841.0                    94738.0
#
#    2020 counts (31 counters)  2021 Counts  Change 2019-2020
# 0                        NaN     0.094627          1.094627
# 1                        NaN     0.179743        117.974253
# 2                        NaN     0.216112        121.611169
# 3                        NaN     0.105645        110.564504
# 4                        NaN     0.249166        124.916602
